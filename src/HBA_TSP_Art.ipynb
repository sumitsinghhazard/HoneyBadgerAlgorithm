# %%
#using Pkg;
#Pkg.add("Flux")
#Pkg.add("TSPLIB")
#Pkg.add("Concorde")
#Pkg.add("Conda")
#Pkg.add("PyCall")
#using Conda
#Conda.add("ezdxf", channel="conda-forge")

# %%
#getting libraries
using Distributions
using Distances
using Random
using Plots
using Statistics
#using Flux
using TSPLIB

# %%
# 2d-world
n=7 # cities

# create n cities in a 1x1 square
x = rand(2,n) 

println(x)
# compute Euclidean distance between cities 
distances=pairwise(Euclidean(), x, dims=2)
# Out:
# [0.022973515526592103 0.5460821976745883 0.4423060220837991 0.06267077011618916 0.832528360224922 0.3037890342793286 0.15873613359932748; 0.5783036464346225 0.03479511782157563 0.1320598416232045 0.430042967758703 0.9580138282466988 0.020793512230175448 0.15086890515607865]
# 7×7 Matrix{Float64}:
#  0.0       0.75435   0.612351  0.153483  0.894181  0.624239  0.448477
#  0.75435   0.0       0.142232  0.624426  0.966636  0.242697  0.404364
#  0.612351  0.142232  0.0       0.482615  0.913495  0.177671  0.284193
#  0.153483  0.624426  0.482615  0.0       0.933506  0.474998  0.29524
#  0.894181  0.966636  0.913495  0.933506  0.0       1.07608   1.05142
#  0.624239  0.242697  0.177671  0.474998  1.07608   0.0       0.194833
#  0.448477  0.404364  0.284193  0.29524   1.05142   0.194833  0.0

# %% [markdown]
# ## TSPLIB Benchmarks

# %% [markdown]
# ## 1) BURMA14

# %%
tsp = readTSPLIB(:burma14)
distances = tsp.weights
println(distances)

# 2d-world
n=tsp.dimension # cities
println("# of cities: ", n)

# optimal value
println("Optimal value: ", tsp.optimal)
# Out:
# [1.0 153.0 510.0 706.0 966.0 581.0 455.0 70.0 160.0 372.0 157.0 567.0 342.0 398.0; 153.0 1.0 422.0 664.0 997.0 598.0 507.0 197.0 311.0 479.0 310.0 581.0 417.0 376.0; 510.0 422.0 1.0 289.0 744.0 390.0 437.0 491.0 645.0 880.0 618.0 374.0 455.0 211.0; 706.0 664.0 289.0 1.0 491.0 265.0 410.0 664.0 804.0 1070.0 768.0 259.0 499.0 310.0; 966.0 997.0 744.0 491.0 1.0 400.0 514.0 902.0 990.0 1261.0 947.0 418.0 635.0 636.0; 581.0 598.0 390.0 265.0 400.0 1.0 168.0 522.0 634.0 910.0 593.0 19.0 284.0 239.0; 455.0 507.0 437.0 410.0 514.0 168.0 1.0 389.0 482.0 757.0 439.0 163.0 124.0 232.0; 70.0 197.0 491.0 664.0 902.0 522.0 389.0 1.0 154.0 406.0 133.0 508.0 273.0 355.0; 160.0 311.0 645.0 804.0 990.0 634.0 482.0 154.0 1.0 276.0 43.0 623.0 358.0 498.0; 372.0 479.0 880.0 1070.0 1261.0 910.0 757.0 406.0 276.0 1.0 318.0 898.0 633.0 761.0; 157.0 310.0 618.0 768.0 947.0 593.0 439.0 133.0 43.0 318.0 1.0 582.0 315.0 464.0; 567.0 581.0 374.0 259.0 418.0 19.0 163.0 508.0 623.0 898.0 582.0 1.0 275.0 221.0; 342.0 417.0 455.0 499.0 635.0 284.0 124.0 273.0 358.0 633.0 315.0 275.0 1.0 247.0; 398.0 376.0 211.0 310.0 636.0 239.0 232.0 355.0 498.0 761.0 464.0 221.0 247.0 1.0]
# # of cities: 14
# Optimal value: 3323.0

# %% [markdown]
# ## 2) BERLIN52

# %%
tsp = readTSPLIB(:berlin52)
distances = tsp.weights
#println(distances)

# 2d-world
n=tsp.dimension # cities
#println("# of cities: ", n)

# optimal value
println("Optimal value: ", tsp.optimal)
# Out:
# Optimal value: 7542.0

# %% [markdown]
# ## 3) EIL101

# %%
tsp = readTSPLIB(:eil101)
distances = tsp.weights
#println(distances)

# 2d-world
n=tsp.dimension # cities
#println("# of cities: ", n)

# optimal value
println("Optimal value: ", tsp.optimal)
# Out:
# Optimal value: 629.0

# %% [markdown]
# ## VLSI Dataset Benchmark

# %% [markdown]
# ## 1) BCL380 - tsp benchamrk from https://www.math.uwaterloo.ca/tsp/vlsi/index.html

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\bcl380.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 380

# %% [markdown]
# ## 2) XQL662 - tsp benchamrk from https://www.math.uwaterloo.ca/tsp/vlsi/index.html

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\xql662.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 662

# %% [markdown]
# ## Art and Examples

# %% [markdown]
# ## 1) Honeybadger 343 art

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\hb.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 343

# %% [markdown]
# ## 2a)Tuffy Construction logo - 2000 points

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\2000tsp.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 2000

# %% [markdown]
# ## 2b) 536 points

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\tuffy_2k.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 536

# %% [markdown]
# ## 3a) HB_1917 points

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\hba-2a.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 1917

# %% [markdown]
# ## 3b) HB_1113 points

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\hba-2.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 1113

# %% [markdown]
# ## 4a) HB-1_597 points

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\hba-1a.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 597

# %% [markdown]
# ## 4b) HB-1_2171

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\hba-1.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 2171

# %% [markdown]
# ## 5) Tuffy-final

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\tuffy_final.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 965

# %% [markdown]
# ## 6) tuffy_476

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\tuffy_476.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 145

# %% [markdown]
# ## 7) ncsu_10k

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\ncsu_1.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 10000

# %% [markdown]
# ## Final

# %%
path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\final_1.tsp"
tsp = readTSP(path)

distances = tsp.weights

n=tsp.dimension # cities
println("# of cities: ", n)
# Out:
# # of cities: 1373

# %% [markdown]
# ### 8) monolisa 100k cities

# %% [markdown]
# path = "C:\\Users\\Barcaboy_Ovid\\ECE 591 Metaheuristic search and Optimization\\Art\\tsp files\\ml.tsp"
# tsp = readTSP(path)
#
# distances = tsp.weights
#
# n=tsp.dimension # cities
# println("# of cities: ", n)

# %% [markdown]
# ## HBA_TSP

# %%
# Define a function to calculate the cumulative probabilities
function cum_probabilities(solution, tour, distances)
    # Initialize an array of zeros to store the probabilities
    probs = zeros(length(solution))
    
    # Calculate the probabilities for each city
    for i in 1:length(solution)
        if i ∉ tour
            probs[i] = (solution[i])  * (1/distances[tour[end], i])
        end
    end
    
    probs /= sum(probs)
    
    # Calculate the cumulative probabilities
    cum_probs = cumsum(probs)
    
    return cum_probs
end
# Out:
# cum_probabilities (generic function with 1 method)

# %%
# Define a function to select the next city based on the probabilities
function select_city(cum_probs)
    # Generate a random number between 0 and 1
    r = rand()
    
    #println("random value: ", r)
    # Find the index of the first cumulative probability that is greater than r
    index = findfirst(cum_probs .>= r)
    #println("next city: ", index)
    return index
end
# Out:
# select_city (generic function with 1 method)

# %%
#generate tour function

function generateTour(solution)
    
    #println("New Tour..")
    # Initialize the tour as an array of zeros
    tour = zeros(Int, n)

    # Set the first city as the one with the smallest value in the solution
    tour[1] = argmin(solution)
    
    # Generate the rest of the tour using the cumulative probabilities
    for i in 2:n
        # Calculate the cumulative probabilities
        cum_probs = cum_probabilities(solution, tour[1:i-1], distances)
        #println("Cum Probs: ", cum_probs)
        #println("Tour so far...: ", tour)
        # Select the next city based on the probabilities
        next_city = select_city(cum_probs)
    
        # Add the next city to the tour
        tour[i] = next_city
    end

    # Print the tour
    #println("The TSP tour is: ", tour)
    return tour
end
# Out:
# generateTour (generic function with 1 method)

# %%
function tour_cost(o::Array{Int64,1})
    n=length(o)
    result = distances[o[n],o[1]]
    for i in 1:(n-1)
        result += distances[o[i],o[i+1]]
    end
    return result
end
# Out:
# tour_cost (generic function with 1 method)

# %%
# create m random vectors of d dimensions in the range [a,b]
function rand_population_uniform(m, d, a, b)
    return [rand(Uniform(a,b),d) for i in 1:m]
end
# Out:
# rand_population_uniform (generic function with 1 method)

# %%
# intensity function

function intensity(N, x, x_prey)
    d = zeros(N)
    S = zeros(N)
    I = zeros(N)
    for i in 1:N-1
        d[i] = euclidean(x[i], x_prey) ^ 2
        S[i] = euclidean(x[i],x[i+1]) ^ 2
    end
    
    d[N] = euclidean(x[N], x_prey)
    S[N] = euclidean(x[N],x[1])
    
    
    
    for i in 1:N
        r2 = rand(Uniform(0,1))
        I[i] = r2 * S[i] / (4 * π * d[i] )
    end
    return I
end
# Out:
# intensity (generic function with 1 method)

# %%
# Honey Badger Algorithm

function HBATSP(t_max, N, beta, C, x)
    # t_max = maximum no of iterations
    # N = population size
    # beta = default value as 6
    # C = default value as 2
    # x = initial population
    # obj_func = benchmark function
    # f = fitness of the population
    # x_prey = best position found so far
    # f_prey = best fitness value so far for the x_prey
    # x_new = new position calculated for the ith honey badger
    # f_new = new fitness calculated for the ith honey badger
    # I = intensity of the honey badger
    # F = disturbance direction
    
    #generate tour from initial solution
    
    
    #calucalte the fitness of each honey badger
    tours = generateTour.(x)
    f = tour_cost.(tours)
    println("fitness vecor: ", f)
    
    #save best posiiton and fitness
    f_prey, x_prey_index = findmin(f)
    x_prey = x[x_prey_index]
    t_prey = tours[x_prey_index]
    
    
    println("best solution: ", x_prey, " fitness: ", f_prey,  " tour: ", t_prey)
    #println("fitness: ", f_prey)
    fitness_values = []
    push!(fitness_values,(0,f_prey))
    for t in 1:t_max
        
        #println("iteration: ", t)
        
        #calculate the density factor / decreasing factor
        alpha = C * exp(-t / t_max)
        #println("alpha: ", alpha)
        
        #calcualte the intensity of the all honey badgers
        I = intensity(N, x, x_prey)
        #println("Intensity: ", I)
        
        for i in 1:N
            
            #calcuate distance between prey and ith honey badger
            d = x_prey - x[i]
            
            #generate disturbance
            r6 = rand(Uniform(0,1))
            if r6<=0.5
                F = 1
            else
                F = -1
            end
            
            
            #generate a random value to deicde between digging vs honey mode
            r2 = rand(Uniform(0,1))
            
            #TODO : if intensity is infinite then go for honey mode
            if isinf(I[i])
                r2 = 0.9
            end
            
            if r2<0.5
                # digging mode
                #println("Digging mode")
                r3 = rand(Uniform(0,1))
                r4 = rand(Uniform(0,1))
                r5 = rand(Uniform(0,1))
                #println("Intensity: ", I[i])
                #p = abs(cos(2*π*r4) * (1 - cos(2*π*r5)))
                #println("cos value: ", p)
                x_new = x_prey + (F * beta * I[i] * x_prey) + (F * r3 * alpha * d * abs(cos(2*π*r4) * (1 - cos(2*π*r5))))
                #f_new = obj_func(x_new)
                t_new = generateTour(x_new)
                f_new = tour_cost(t_new)
            
            else
                # honey node
                #println("Honey mode")
                r7 = rand(Uniform(0,1))
                x_new = x_prey + (F * r7 * alpha * d)
                #f_new = obj_func(x_new)
                t_new = generateTour(x_new)
                f_new = tour_cost(t_new)
            end
            
            #TODO: mange xnew to be within the bounds
            
            # evaluate the new posiiton and fitness values
            
            #local position update
            if f_new < f[i]
                #println("local position is improved")
                #println("values", x[i], ";", x_new, ";", f[i], ";", f_new  )
                x[i] = x_new
                f[i] = f_new
                
                #println("local position is improved fin")
            end
            
            #prey position update
            if f_new<f_prey
                println("prey position is improved with honey badger # ", i, " in iteration # ", t)
                x_prey = x_new
                f_prey = f_new
                t_prey = t_new
                println("best solution: ", x_prey, " fitness: ", f_prey,  " tour: ", t_prey)
                push!(fitness_values,(t,f_prey))
            end
            
        end
        #push!(fitness_values,(t,f_prey))
        #println("fitness: ", f_prey)
    end
    return x_prey, f_prey, t_prey, fitness_values 
end
# Out:
# HBATSP (generic function with 1 method)

# %%
@time begin
#dimensions = # of cities
d = n
#lower bound
a = 0
#upper bound
b = 1
# population size
N = 4
#iterations
t_max = 10
#constant beta
beta = 6
#constant C
C = 2


x = rand_population_uniform(N, d, a, b )
x_prey, t_prey, f_prey, fitness_values = HBATSP(t_max, N, beta, C, x)

end
println("Best solution: ", x_prey)
println("Best tour: ", t_prey)
println("Best cost: ", f_prey)
println("Fitness values: ", fitness_values)

# %%
using Random
using Luxor

function draw_tsp(y,o,n,size=1000,radius=5)
    Drawing(size, size, "TSP.png")
    stretch=Int64(0.9size)
    origin(Int64(0.05size),Int64(0.05size))
    # draw cities
    for i in 1:n
        A=Point(stretch*y[1,i],stretch*y[2,i])
        circle(A, radius, :fill)
        label("city $i", :S, A)
    end
    # connect cities by edges
    for i in 1:n-1
        A=Point(stretch*y[1,o[i]],stretch*y[2,o[i]])
        B=Point(stretch*y[1,o[i+1]],stretch*y[2,o[i+1]])
        line(A, B, :stroke)
    end
    # return to first city
    A=Point(stretch*y[1,o[n]],stretch*y[2,o[n]])
    B=Point(stretch*y[1,o[1]],stretch*y[2,o[1]])
    line(A, B, :stroke)
    finish()
    preview()
end
# Out:
# draw_tsp (generic function with 3 methods)

# %%
x = tsp.nodes
gr()
#println(x)
y = reshape(x,2,n)
#println(y)
#draw_tsp(y, f_prey, n)
# Out:
# 2×1373 Matrix{Float64}:
#  1657.27  1666.6  1682.54  1684.15  1680.02  …  -528.889  -515.227  -507.809
#  1663.51  1673.9  1682.7   1686.27  1675.9      -522.226  -516.829  -505.99

# %% [markdown]
# ## Initial

# %%
x = tsp.nodes

using Plots

data = x

# Create a scatter plot of the points
scatter(data[:,1], data[:,2], legend=false)

# Add lines connecting the points in the order they appear in the data
plot!(data[:,1], data[:,2], seriestype=:path)

# %%
using Plots

data = x

# Create a scatter plot of the points
scatter(data[:,1], data[:,2], legend=false)

# Add lines connecting the points in the order they appear in the data
plot(data[:,1], data[:,2], seriestype=:path)

# %% [markdown]
# ## Closed Loop

# %%
x = tsp.nodes

using Plots

# Define the data
data = x

# Add the first point to the end of the data to connect the last and first points
closed_data = vcat(data, data[1:1, :])

# Create a scatter plot of the points
scatter(data[:, 1], data[:, 2], legend=false)

# Add lines connecting the points in the order they appear in the closed_data
plot!(closed_data[:, 1], closed_data[:, 2], seriestype=:path)

# %%
x = tsp.nodes

using Plots

# Define the data
data = x

# Add the first point to the end of the data to connect the last and first points
closed_data = vcat(data, data[1:1, :])

# Create a scatter plot of the points
scatter(data[:, 1], data[:, 2], legend=false)

# Add lines connecting the points in the order they appear in the closed_data
plot(closed_data[:, 1], closed_data[:, 2], seriestype=:path)

# %%
using PyCall
ezdxf = pyimport("ezdxf")

data = x

#doc to store values
doc = ezdxf.new("R2010")

# creating alyer for TSP
msp = doc.modelspace()
layer = doc.layers.new("tsp", dxfattribs=Dict("color" => 7))

for i in 1:(size(data, 1) - 1)
    msp.add_line(data[i, :], data[i + 1, :], dxfattribs=Dict("layer" => "tsp"))
end
# connect last and first point.
msp.add_line(data[end, :], data[1, :], dxfattribs=Dict("layer" => "tsp"))
doc.saveas("tsp.dxf")
